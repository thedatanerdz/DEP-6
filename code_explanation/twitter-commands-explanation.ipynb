# %%
sudo apt-get update
sudo apt install python3-pip
sudo pip install apache-airflow
sudo pip install pandas 
sudo pip install s3fs
sudo pip install tweepy

# %% [markdown]
# The provided file, twitter_commands.sh, appears to contain a list of commands to be executed in a Linux-based environment. These commands are used to update the package lists, install various Python packages, and set up the required dependencies for using Apache Airflow, pandas, s3fs, and tweepy.
#
# To run the twitter_commands.sh script, follow these steps:
#
# Make sure you are on a Linux-based system or a compatible environment (e.g., WSL on Windows).
#
# Open the terminal or command-line interface on your system.
#
# Navigate to the directory where the twitter_commands.sh file is located. You can use the cd command to change directories. For example, if the file is in the ~/Downloads directory, you can do:

# %%
cd ~/Downloads

# %% [markdown]
# Before running the script, ensure that the file has the necessary execute permissions. You can grant execute permissions using the chmod command:

# %%
chmod +x twitter_commands.sh

# %% [markdown]
# Now, you can run the script by typing its name preceded by ./ (dot slash):

# %%
./twitter_commands.sh

# %% [markdown]
# The script will start executing the commands one by one. You may be prompted to enter your system password for some of the commands (e.g., sudo apt-get update and sudo apt install python3-pip). This is because some of the commands require administrative privileges.
#
# Wait for the script to finish executing. It will update the package lists, install the required Python packages (apache-airflow, pandas, s3fs, and tweepy) using pip.
#
# After the script completes successfully, you should have Apache Airflow, pandas, s3fs, and tweepy installed on your system, along with their dependencies.
#
# Please note that using sudo in scripts can be potentially dangerous, as it grants elevated privileges to the commands. Make sure you understand the implications and only run scripts from trusted sources. Additionally, if you are on a system that does not use apt-get as the package manager (e.g., macOS), the package installation commands may differ, and you need to adapt the script accordingly.
